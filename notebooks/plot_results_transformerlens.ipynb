# %% [markdown]
# Let's try to experiment with Pythia-12B and TransformerLens

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import random
import yaml
from omegaconf import DictConfig, OmegaConf
from interventions import three_operands
from tqdm.notebook import tqdm
import numpy as np
from functools import partial

import transformer_lens.utils as utils
from transformer_lens import ActivationCache, HookedTransformer
import transformer_lens.patching as patching
import seaborn as sns
import matplotlib.pyplot as plt

seed = 0

# %%
random.seed(seed)
torch.manual_seed(seed)
torch.set_grad_enabled(False)

# %%
model_name = 'EleutherAI/pythia-12b-deduped-v0'
model_name_lens = 'pythia-12b-deduped-v0'
# model_name = 'EleutherAI/pythia-6.9b-deduped-v0'
# model_name_lens = 'pythia-6.9b-deduped-v0'
# model_name_lens = 'facebook/opt-125m'
tokenizer = AutoTokenizer.from_pretrained(model_name)

# model = AutoModelForCausalLM.from_pretrained(
#     model_name,
#     load_in_8bit=True,
#     torch_dtype=torch.float16,
#     cache_dir=None,
#     device_map="auto"
# )

# conf = OmegaConf.load('conf/config.yaml')
# intervention_list = three_operands.get_arithmetic_data_three_operands(tokenizer, conf)

# %%
model = HookedTransformer.from_pretrained(
    model_name_lens,
    dtype=torch.bfloat16
)
model.eval();

# These parameters might be useful in the future
# center_unembed=True,
# center_writing_weights=True,
# fold_ln=True,
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:With reduced precision, it is advised to use `from_pretrained_no_processing` instead of `from_pretrained`.
# Loaded pretrained model pythia-12b-deduped-v0 into HookedTransformer

# %%
example_prompt = "After John and Mary went to the store, John gave a bottle of milk to"
example_answer = " Mary"
utils.test_prompt(example_prompt, example_answer, model, prepend_bos=True)
# Out:
# Tokenized prompt: ['<|endoftext|>', 'After', ' John', ' and', ' Mary', ' went', ' to', ' the', ' store', ',', ' John', ' gave', ' a', ' bottle', ' of', ' milk', ' to']
# Tokenized answer: [' Mary']
# Performance on answer token:
# Rank: 0        Logit: 16.62 Prob: 30.47% Token: | Mary|
# Top 0th token. Logit: 16.62 Prob: 30.47% Token: | Mary|
# Top 1th token. Logit: 16.12 Prob: 18.46% Token: | the|
# Top 2th token. Logit: 15.94 Prob: 15.23% Token: | his|
# Top 3th token. Logit: 15.44 Prob:  9.28% Token: | a|
# Top 4th token. Logit: 13.94 Prob:  2.06% Token: | their|
# Top 5th token. Logit: 12.88 Prob:  0.71% Token: | each|
# Top 6th token. Logit: 12.69 Prob:  0.59% Token: | Sarah|
# Top 7th token. Logit: 12.50 Prob:  0.49% Token: | Sam|
# Top 8th token. Logit: 12.50 Prob:  0.49% Token: | baby|
# Top 9th token. Logit: 12.44 Prob:  0.46% Token: |
# |
# Ranks of the answer tokens: [(' Mary', 0)]

# %%
conf = OmegaConf.load('conf/config.yaml')
intervention_list = three_operands.get_arithmetic_data_three_operands(tokenizer, conf)
# Out:
#  45%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                                                                     | 95/210 [00:00<00:00, 906.31it/s]
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('3', '5', '6')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ6']
# base string tok list:  [21, 559, 577, 559, 721, 426, 1638, 15, 495, 559, 608, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  608
# x_base_tok:  495
# res base: 17
# res base wo whitespace: 7
# res base with prefix: a 17
# res base tok: ['a', 'Ġ17']
# operands_base:  ('3', '7', '7')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ7']
# base string tok list:  [20, 559, 374, 559, 854, 426, 2145, 15, 495, 559, 818, 559, 818, 426]
# z_base_tok:  818
# y_base_tok:  818
# x_base_tok:  495
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('8', '2', '2')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [21, 559, 374, 559, 854, 426, 1638, 15, 854, 559, 374, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  854
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('2', '6', '6')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ6']
# base string tok list:  [740, 559, 374, 559, 495, 426, 1458, 15, 374, 559, 721, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  721
# x_base_tok:  374
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('8', '6', '5')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ5']
# base string tok list:  [22, 559, 577, 559, 374, 426, 1903, 15, 854, 559, 721, 559, 608, 426]
# z_base_tok:  608
# y_base_tok:  721
# x_base_tok:  854
# res base: 11
# res base wo whitespace: 1
# res base with prefix: a 11
# res base tok: ['a', 'Ġ11']
# operands_base:  ('6', '2', '3')
# x_base_tok:  ['Ġ6']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [26, 559, 374, 559, 374, 426, 2145, 15, 721, 559, 374, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  721
# res base: 17
# res base wo whitespace: 7
# res base with prefix: a 17
# res base tok: ['a', 'Ġ17']
# operands_base:  ('2', '9', '6')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ6']
# base string tok list:  [21, 559, 721, 559, 854, 426, 1283, 15, 374, 559, 898, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  898
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('5', '10', '3')
# x_base_tok:  ['Ġ5']
# y_base_tok:  ['Ġ10']
# z_base_tok:  ['Ġ3']
# base string tok list:  [20, 559, 721, 559, 374, 426, 1903, 15, 608, 559, 884, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  884
# x_base_tok:  608
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('4', '9', '5')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ5']
# base string tok list:  [20, 559, 495, 559, 818, 426, 2145, 15, 577, 559, 898, 559, 608, 426]
# z_base_tok:  608
# y_base_tok:  898
# x_base_tok:  577
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('2', '9', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ3']
# base string tok list:  [22, 559, 608, 559, 818, 426, 1722, 15, 374, 559, 898, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  898
# x_base_tok:  374
# res base: 15
# res base wo whitespace: 5
# res base with prefix: a 15
# res base tok: ['a', 'Ġ15']
# operands_base:  ('2', '10', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ10']
# z_base_tok:  ['Ġ3']
# base string tok list:  [26, 559, 374, 559, 818, 426, 1283, 15, 374, 559, 884, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  884
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('7', '4', '7')
# x_base_tok:  ['Ġ7']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ7']
# base string tok list:  [24, 559, 374, 559, 721, 426, 1458, 15, 818, 559, 577, 559, 818, 426]
# z_base_tok:  818
# y_base_tok:  577
# x_base_tok:  818
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('2', '4', '8')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ8']
# base string tok list:  [21, 559, 1903, 559, 374, 426, 1722, 15, 374, 559, 577, 559, 854, 426]
# z_base_tok:  854
# y_base_tok:  577
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('5', '5', '2')
# x_base_tok:  ['Ġ5']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ2']
# base string tok list:  [805, 559, 374, 559, 577, 426, 1283, 15, 608, 559, 608, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  608
# x_base_tok:  608
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '2', '12')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ12']
# base string tok list:  [20, 559, 374, 559, 1638, 426, 655, 15, 374, 559, 374, 559, 1249, 426]
# z_base_tok:  1249
# y_base_tok:  374
# x_base_tok:  374
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('6', '6', '2')
# x_base_tok:  ['Ġ6']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ2']
# base string tok list:  [23, 559, 721, 559, 608, 426, 1722, 15, 721, 559, 721, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  721
# x_base_tok:  721
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('4', '4', '11')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ11']
# base string tok list:  [22, 559, 721, 559, 495, 426, 1638, 15, 577, 559, 577, 559, 1903, 426]
# z_base_tok:  1903
# y_base_tok:  577
# x_base_tok:  577
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('2', '6', '6')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ6']
# base string tok list:  [19, 559, 721, 559, 608, 426, 2145, 15, 374, 559, 721, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  721
# x_base_tok:  374
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('3', '2', '14')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ14']
# base string tok list:  [20, 559, 495, 559, 721, 426, 1249, 15, 495, 559, 374, 559, 1638, 426]
# z_base_tok:  1638
# y_base_tok:  374
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('11', '3', '2')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [23, 559, 374, 559, 608, 426, 2145, 15, 1903, 559, 495, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  1903
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('11', '2', '6')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ6']
# base string tok list:  [22, 559, 818, 559, 721, 426, 1283, 15, 1903, 559, 374, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  374
# x_base_tok:  1903
# res base: 11
# res base wo whitespace: 1
# res base with prefix: a 11
# res base tok: ['a', 'Ġ11']
# operands_base:  ('3', '2', '6')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ6']
# base string tok list:  [19, 559, 374, 559, 818, 426, 1903, 15, 495, 559, 374, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  374
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('4', '6', '6')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ6']
# base string tok list:  [22, 559, 1249, 559, 374, 426, 655, 15, 577, 559, 721, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  721
# x_base_tok:  577
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('8', '7', '4')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ4']
# base string tok list:  [21, 559, 577, 559, 577, 426, 1249, 15, 854, 559, 818, 559, 577, 426]
# z_base_tok:  577
# y_base_tok:  818
# x_base_tok:  854
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('6', '6', '6')
# x_base_tok:  ['Ġ6']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ6']
# base string tok list:  [25, 559, 495, 559, 854, 426, 655, 15, 721, 559, 721, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  721
# x_base_tok:  721
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('6', '2', '4')
# x_base_tok:  ['Ġ6']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [24, 559, 374, 559, 884, 426, 655, 15, 721, 559, 374, 559, 577, 426]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  721
# res base: 15
# res base wo whitespace: 5
# res base with prefix: a 15
# res base tok: ['a', 'Ġ15']
# operands_base:  ('5', '7', '3')
# x_base_tok:  ['Ġ5']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ3']
# base string tok list:  [19, 559, 608, 559, 1249, 426, 655, 15, 608, 559, 818, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  818
# x_base_tok:  608
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('11', '3', '2')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [24, 559, 608, 559, 608, 426, 1722, 15, 1903, 559, 495, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  1903
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('6', '7', '5')
# x_base_tok:  ['Ġ6']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ5']
# base string tok list:  [21, 559, 608, 559, 854, 426, 1722, 15, 721, 559, 818, 559, 608, 426]
# z_base_tok:  608
# y_base_tok:  818
# x_base_tok:  721
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('4', '10', '2')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ10']
# z_base_tok:  ['Ġ2']
# base string tok list:  [740, 559, 374, 559, 374, 426, 1638, 15, 577, 559, 884, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  884
# x_base_tok:  577
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('7', '4', '8')
# x_base_tok:  ['Ġ7']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ8']
# base string tok list:  [510, 906, 273, 884, 559, 608, 559, 495, 426, 1283, 15, 380, 906, 273, 818, 559, 577, 559, 854, 426]
# z_base_tok:  854
# y_base_tok:  577
# x_base_tok:  818
# res base: 15
# res base wo whitespace: 5
# res base with prefix: a 15
# res base tok: ['a', 'Ġ15']
# operands_base:  ('8', '4', '3')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 898, 559, 577, 559, 721, 426, 655, 15, 380, 906, 273, 854, 559, 577, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  577
# x_base_tok:  854
# res base: 15
# res base wo whitespace: 5
# res base with prefix: a 15
# res base tok: ['a', 'Ġ15']
# operands_base:  ('2', '7', '6')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ6']
# base string tok list:  [510, 906, 273, 818, 559, 608, 559, 495, 426, 1458, 15, 380, 906, 273, 374, 559, 818, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  818
# x_base_tok:  374
# res base: 9
# res base wo whitespace:
# res base with prefix: a 9
# res base tok: ['a', 'Ġ9']
# operands_base:  ('4', '2', '3')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 818, 559, 577, 559, 577, 426, 1458, 15, 380, 906, 273, 577, 559, 374, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  577
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('8', '3', '8')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ8']
# base string tok list:  [510, 906, 273, 495, 559, 577, 559, 721, 426, 2145, 15, 380, 906, 273, 854, 559, 495, 559, 854, 426]
# z_base_tok:  854
# y_base_tok:  495
# x_base_tok:  854
# res base: 11
# res base wo whitespace: 1
# res base with prefix: a 11
# res base tok: ['a', 'Ġ11']
# operands_base:  ('2', '7', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 608, 559, 1249, 559, 374, 426, 655, 15, 380, 906, 273, 374, 559, 818, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  818
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('6', '10', '2')
# x_base_tok:  ['Ġ6']
# y_base_tok:  ['Ġ10']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 608, 559, 721, 559, 495, 426, 1638, 15, 380, 906, 273, 721, 559, 884, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  884
# x_base_tok:  721
# res base: 10
# res base wo whitespace: 0
# res base with prefix: a 10
# res base tok: ['a', 'Ġ10']
# operands_base:  ('3', '4', '3')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 818, 559, 495, 559, 608, 426, 1458, 15, 380, 906, 273, 495, 559, 577, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  577
# x_base_tok:  495
# res base: 17
# res base wo whitespace: 7
# res base with prefix: a 17
# res base tok: ['a', 'Ġ17']
# operands_base:  ('5', '7', '5')
# x_base_tok:  ['Ġ5']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ5']
# base string tok list:  [510, 906, 273, 374, 559, 2145, 559, 495, 426, 1283, 15, 380, 906, 273, 608, 559, 818, 559, 608, 426]
# z_base_tok:  608
# y_base_tok:  818
# x_base_tok:  608
# res base: 17
# res base wo whitespace: 7
# res base with prefix: a 17
# res base tok: ['a', 'Ġ17']
# operands_base:  ('9', '6', '2')
# x_base_tok:  ['Ġ9']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 608, 559, 818, 559, 608, 426, 1722, 15, 380, 906, 273, 898, 559, 721, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  721
# x_base_tok:  898
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('3', '4', '9')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ9']
# base string tok list:  [510, 906, 273, 608, 559, 608, 559, 721, 426, 1668, 15, 380, 906, 273, 495, 559, 577, 559, 898, 426]
# z_base_tok:  898
# y_base_tok:  577
# x_base_tok:  495
# res base: 9
# res base wo whitespace:
# res base with prefix: a 9
# res base tok: ['a', 'Ġ9']
# operands_base:  ('3', '3', '3')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 818, 559, 721, 559, 374, 426, 1458, 15, 380, 906, 273, 495, 559, 495, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  495
# x_base_tok:  495
# res base: 10
# res base wo whitespace: 0
# res base with prefix: a 10
# res base tok: ['a', 'Ġ10']
# operands_base:  ('4', '3', '3')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 374, 559, 884, 559, 721, 426, 1283, 15, 380, 906, 273, 577, 559, 495, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  495
# x_base_tok:  577
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('10', '2', '6')
# x_base_tok:  ['Ġ10']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ6']
# base string tok list:  [510, 906, 273, 608, 559, 818, 559, 495, 426, 1458, 15, 380, 906, 273, 884, 559, 374, 559, 721, 426]
# z_base_tok:  721
# y_base_tok:  374
# x_base_tok:  884
# res base: 17
# res base wo whitespace: 7
# res base with prefix: a 17
# res base tok: ['a', 'Ġ17']
# operands_base:  ('2', '12', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ12']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 608, 559, 374, 559, 721, 426, 2145, 15, 380, 906, 273, 374, 559, 1249, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  1249
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('4', '12', '2')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ12']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 898, 559, 495, 559, 495, 426, 1458, 15, 380, 906, 273, 577, 559, 1249, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  1249
# x_base_tok:  577
# res base: 13
# res base wo whitespace: 3
# res base with prefix: a 13
# res base tok: ['a', 'Ġ13']
# operands_base:  ('8', '2', '3')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 577, 559, 854, 559, 818, 426, 655, 15, 380, 906, 273, 854, 559, 374, 559, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  854
# res base: 17
# res base wo whitespace: 7
# res base with prefix: a 17
# res base tok: ['a', 'Ġ17']
# operands_base:  ('10', '3', '4')
# x_base_tok:  ['Ġ10']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 577, 559, 884, 559, 495, 426, 1722, 15, 380, 906, 273, 884, 559, 495, 559, 577, 426]
# z_base_tok:  577
# y_base_tok:  495
# x_base_tok:  884
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('5', '3', '4')
# x_base_tok:  ['Ġ5']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 495, 559, 608, 559, 608, 426, 2145, 15, 380, 906, 273, 608, 559, 495, 559, 577, 426]
# z_base_tok:  577
# y_base_tok:  495
# x_base_tok:  608
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('10', '4', '2')
# x_base_tok:  ['Ġ10']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 559, 608, 559, 721, 426, 1638, 15, 380, 906, 273, 884, 559, 577, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  577
# x_base_tok:  884
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('11', '6', '2')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 577, 559, 577, 559, 577, 426, 1249, 15, 380, 906, 273, 1903, 559, 721, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  721
# x_base_tok:  1903
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('2', '9', '7')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ7']
# base string tok list:  [510, 906, 273, 818, 559, 374, 559, 374, 426, 1903, 15, 380, 906, 273, 374, 559, 898, 559, 818, 426]
# z_base_tok:  818
# y_base_tok:  898
# x_base_tok:  374
# res base: 15
# res base wo whitespace: 5
# res base with prefix: a 15
# res base tok: ['a', 'Ġ15']
# operands_base:  ('3', '2', '10')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ10']
# base string tok list:  [510, 906, 273, 495, 559, 577, 559, 577, 426, 1903, 15, 380, 906, 273, 495, 559, 374, 559, 884, 426]
# z_base_tok:  884
# y_base_tok:  374
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('5', '3', '8')
# x_base_tok:  ['Ġ5']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ8']
# base string tok list:  [510, 906, 273, 608, 559, 577, 559, 495, 426, 1249, 15, 380, 906, 273, 608, 559, 495, 559, 854, 426]
# z_base_tok:  854
# y_base_tok:  495
# x_base_tok:  608
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('9', '7', '2')
# x_base_tok:  ['Ġ9']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 559, 721, 559, 577, 426, 2145, 15, 380, 906, 273, 898, 559, 818, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  818
# x_base_tok:  898
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('3', '2', '9')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ9']
# base string tok list:  [510, 906, 273, 577, 559, 818, 559, 495, 426, 1638, 15, 380, 906, 273, 495, 559, 374, 559, 898, 426]
# z_base_tok:  898
# y_base_tok:  374
# x_base_tok:  495
# res base: 13
# res base wo whitespace: 3
# res base with prefix: a 13
# res base tok: ['a', 'Ġ13']
# operands_base:  ('2', '9', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 608, 559, 577, 559, 898, 426, 1283, 15, 380, 906, 273, 374, 559, 898, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  898
# x_base_tok:  374
# res base: 8
# res base wo whitespace:
# res base with prefix: a 8
# res base tok: ['a', 'Ġ8']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 559, 608, 559, 608, 426, 2145, 15, 380, 906, 273, 495, 559, 495, 559, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('8', '2', '8')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ8']
# base string tok list:  [510, 906, 273, 495, 559, 374, 559, 721, 426, 1903, 15, 380, 906, 273, 854, 559, 374, 559, 854, 426]
# z_base_tok:  854
# y_base_tok:  374
# x_base_tok:  854
# res base: 19
# res base wo whitespace: 9
# res base with prefix: a 19
# res base tok: ['a', 'Ġ19']
# operands_base:  ('9', '6', '4')
# x_base_tok:  ['Ġ9']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 884, 559, 495, 559, 495, 426, 1668, 15, 380, 906, 273, 898, 559, 721, 559, 577, 426]
# z_base_tok:  577
# y_base_tok:  721
# x_base_tok:  898
# res base: 5
# res base wo whitespace:
# res base with prefix: a 5
# res base tok: ['a', 'Ġ5']
# operands_base:  ('15', '5', '5')
# x_base_tok:  ['Ġ15']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ5']
# base string tok list:  [510, 906, 273, 1384, 19734, 608, 19734, 1638, 310, 337, 15, 380, 906, 273, 1458, 19734, 608, 19734, 608, 310]
# z_base_tok:  608
# y_base_tok:  608
# x_base_tok:  1458
# res base: 4
# res base wo whitespace:
# res base with prefix: a 4
# res base tok: ['a', 'Ġ4']
# operands_base:  ('17', '5', '8')
# x_base_tok:  ['Ġ17']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ8']
# base string tok list:  [510, 906, 273, 1722, 19734, 577, 19734, 854, 310, 608, 15, 380, 906, 273, 1722, 19734, 608, 19734, 854, 310]
# z_base_tok:  854
# y_base_tok:  608
# x_base_tok:  1722
# res base: 7
# res base wo whitespace:
# res base with prefix: a 7
# res base tok: ['a', 'Ġ7']
# operands_base:  ('18', '3', '8')
# x_base_tok:  ['Ġ18']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ8']
# base string tok list:  [510, 906, 273, 1249, 19734, 721, 19734, 608, 310, 337, 15, 380, 906, 273, 1283, 19734, 495, 19734, 854, 310]
# z_base_tok:  854
# y_base_tok:  495
# x_base_tok:  1283
# res base: 1
# res base wo whitespace:
# res base with prefix: a 1
# res base tok: ['a', 'Ġ1']
# operands_base:  ('16', '10', '5')
# x_base_tok:  ['Ġ16']
# y_base_tok:  ['Ġ10']
# z_base_tok:  ['Ġ5']
# base string tok list:  [510, 906, 273, 1283, 19734, 608, 19734, 374, 310, 1903, 15, 380, 906, 273, 1668, 19734, 884, 19734, 608, 310]
# z_base_tok:  608
# y_base_tok:  884
# x_base_tok:  1668
# res base: 5
# res base wo whitespace:
# res base with prefix: a 5
# res base tok: ['a', 'Ġ5']
# operands_base:  ('20', '13', '2')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ13']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 2145, 19734, 854, 19734, 374, 310, 495, 15, 380, 906, 273, 1384, 19734, 2145, 19734, 374, 310]
# z_base_tok:  374
# y_base_tok:  2145
# x_base_tok:  1384
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('20', '2', '15')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ15']
# base string tok list:  [510, 906, 273, 1458, 19734, 495, 19734, 495, 310, 898, 15, 380, 906, 273, 1384, 19734, 374, 19734, 1458, 310]
# z_base_tok:  1458
# y_base_tok:  374
# x_base_tok:  1384
# res base: 4
# res base wo whitespace:
# res base with prefix: a 4
# res base tok: ['a', 'Ġ4']
# operands_base:  ('11', '5', '2')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 2145, 19734, 818, 19734, 608, 310, 337, 15, 380, 906, 273, 1903, 19734, 608, 19734, 374, 310]
# z_base_tok:  374
# y_base_tok:  608
# x_base_tok:  1903
# res base: 5
# res base wo whitespace:
# res base with prefix: a 5
# res base tok: ['a', 'Ġ5']
# operands_base:  ('17', '8', '4')
# x_base_tok:  ['Ġ17']
# y_base_tok:  ['Ġ8']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 655, 19734, 374, 19734, 854, 310, 898, 15, 380, 906, 273, 1722, 19734, 854, 19734, 577, 310]
# z_base_tok:  577
# y_base_tok:  854
# x_base_tok:  1722
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('20', '11', '6')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ11']
# z_base_tok:  ['Ġ6']
# base string tok list:  [510, 906, 273, 1722, 19734, 495, 19734, 374, 310, 1249, 15, 380, 906, 273, 1384, 19734, 1903, 19734, 721, 310]
# z_base_tok:  721
# y_base_tok:  1903
# x_base_tok:  1384
# res base: 4
# res base wo whitespace:
# res base with prefix: a 4
# res base tok: ['a', 'Ġ4']
# operands_base:  ('12', '2', '6')
# x_base_tok:  ['Ġ12']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ6']
# base string tok list:  [510, 906, 273, 655, 19734, 721, 19734, 818, 310, 721, 15, 380, 906, 273, 1249, 19734, 374, 19734, 721, 310]
# z_base_tok:  721
# y_base_tok:  374
# x_base_tok:  1249
# res base: 4
# res base wo whitespace:
# res base with prefix: a 4
# res base tok: ['a', 'Ġ4']
# operands_base:  ('17', '3', '10')
# x_base_tok:  ['Ġ17']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ10']
# base string tok list:  [510, 906, 273, 655, 19734, 1638, 19734, 495, 310, 374, 15, 380, 906, 273, 1722, 19734, 495, 19734, 884, 310]
# z_base_tok:  884
# y_base_tok:  495
# x_base_tok:  1722
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('20', '15', '2')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ15']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 1283, 19734, 577, 19734, 2145, 310, 337, 15, 380, 906, 273, 1384, 19734, 1458, 19734, 374, 310]
# z_base_tok:  374
# y_base_tok:  1458
# x_base_tok:  1384
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('17', '12', '2')
# x_base_tok:  ['Ġ17']
# y_base_tok:  ['Ġ12']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 1249, 19734, 374, 19734, 374, 310, 854, 15, 380, 906, 273, 1722, 19734, 1249, 19734, 374, 310]
# z_base_tok:  374
# y_base_tok:  1249
# x_base_tok:  1722
# res base: 2
# res base wo whitespace:
# res base with prefix: a 2
# res base tok: ['a', 'Ġ2']
# operands_base:  ('15', '3', '10')
# x_base_tok:  ['Ġ15']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ10']
# base string tok list:  [510, 906, 273, 1638, 19734, 854, 19734, 495, 310, 495, 15, 380, 906, 273, 1458, 19734, 495, 19734, 884, 310]
# z_base_tok:  884
# y_base_tok:  495
# x_base_tok:  1458
# res base: 5
# res base wo whitespace:
# res base with prefix: a 5
# res base tok: ['a', 'Ġ5']
# operands_base:  ('19', '5', '9')
# x_base_tok:  ['Ġ19']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ9']
# base string tok list:  [510, 906, 273, 1638, 19734, 495, 19734, 721, 310, 608, 15, 380, 906, 273, 655, 19734, 608, 19734, 898, 310]
# z_base_tok:  898
# y_base_tok:  608
# x_base_tok:  655
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('9', '2', '4')
# x_base_tok:  ['Ġ9']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 1638, 19734, 608, 19734, 374, 310, 818, 15, 380, 906, 273, 898, 19734, 374, 19734, 577, 310]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  898
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('20', '2', '4')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 1249, 19734, 854, 19734, 374, 310, 374, 15, 380, 906, 273, 1384, 19734, 374, 19734, 577, 310]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  1384
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('18', '3', '12')
# x_base_tok:  ['Ġ18']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ12']
# base string tok list:  [510, 906, 273, 655, 19734, 1249, 19734, 608, 310, 374, 15, 380, 906, 273, 1283, 19734, 495, 19734, 1249, 310]
# z_base_tok:  1249
# y_base_tok:  495
# x_base_tok:  1283
# res base: 13
# res base wo whitespace: 3
# res base with prefix: a 13
# res base tok: ['a', 'Ġ13']
# operands_base:  ('19', '3', '3')
# x_base_tok:  ['Ġ19']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 1384, 19734, 721, 19734, 818, 310, 818, 15, 380, 906, 273, 655, 19734, 495, 19734, 495, 310]
# z_base_tok:  495
# y_base_tok:  495
# x_base_tok:  655
# res base: 8
# res base wo whitespace:
# res base with prefix: a 8
# res base tok: ['a', 'Ġ8']
# operands_base:  ('17', '2', '7')
# x_base_tok:  ['Ġ17']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ7']
# base string tok list:  [510, 906, 273, 2145, 19734, 495, 19734, 721, 310, 577, 15, 380, 906, 273, 1722, 19734, 374, 19734, 818, 310]
# z_base_tok:  818
# y_base_tok:  374
# x_base_tok:  1722
# res base: 8
# res base wo whitespace:
# res base with prefix: a 8
# res base tok: ['a', 'Ġ8']
# operands_base:  ('15', '5', '2')
# x_base_tok:  ['Ġ15']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 1458, 19734, 495, 19734, 1903, 310, 337, 15, 380, 906, 273, 1458, 19734, 608, 19734, 374, 310]
# z_base_tok:  374
# y_base_tok:  608
# x_base_tok:  1458
# res base: 2
# res base wo whitespace:
# res base with prefix: a 2
# res base tok: ['a', 'Ġ2']
# operands_base:  ('12', '3', '7')
# x_base_tok:  ['Ġ12']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ7']
# base string tok list:  [510, 906, 273, 1722, 19734, 577, 19734, 721, 310, 818, 15, 380, 906, 273, 1249, 19734, 495, 19734, 818, 310]
# z_base_tok:  818
# y_base_tok:  495
# x_base_tok:  1249
# res base: 5
# res base wo whitespace:
# res base with prefix: a 5
# res base tok: ['a', 'Ġ5']
# operands_base:  ('20', '5', '10')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ10']
# base string tok list:  [510, 906, 273, 1458, 19734, 1249, 19734, 374, 310, 337, 15, 380, 906, 273, 1384, 19734, 608, 19734, 884, 310]
# z_base_tok:  884
# y_base_tok:  608
# x_base_tok:  1384
# res base: 11
# res base wo whitespace: 1
# res base with prefix: a 11
# res base tok: ['a', 'Ġ11']
# operands_base:  ('20', '4', '5')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ5']
# base string tok list:  [510, 906, 273, 1384, 19734, 495, 19734, 898, 310, 854, 15, 380, 906, 273, 1384, 19734, 577, 19734, 608, 310]
# z_base_tok:  608
# y_base_tok:  577
# x_base_tok:  1384
# res base: 1
# res base wo whitespace:
# res base with prefix: a 1
# res base tok: ['a', 'Ġ1']
# operands_base:  ('9', '3', '5')
# x_base_tok:  ['Ġ9']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ5']
# base string tok list:  [510, 906, 273, 655, 19734, 898, 19734, 898, 310, 337, 15, 380, 906, 273, 898, 19734, 495, 19734, 608, 310]
# z_base_tok:  608
# y_base_tok:  495
# x_base_tok:  898
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('11', '4', '4')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 884, 19734, 577, 19734, 374, 310, 577, 15, 380, 906, 273, 1903, 19734, 577, 19734, 577, 310]
# z_base_tok:  577
# y_base_tok:  577
# x_base_tok:  1903
# res base: 13
# res base wo whitespace: 3
# res base with prefix: a 13
# res base tok: ['a', 'Ġ13']
# operands_base:  ('20', '5', '2')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 1458, 19734, 495, 19734, 577, 310, 854, 15, 380, 906, 273, 1384, 19734, 608, 19734, 374, 310]
# z_base_tok:  374
# y_base_tok:  608
# x_base_tok:  1384
# res base: 5
# res base wo whitespace:
# res base with prefix: a 5
# res base tok: ['a', 'Ġ5']
# operands_base:  ('20', '11', '4')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ11']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 1668, 19734, 495, 19734, 495, 310, 884, 15, 380, 906, 273, 1384, 19734, 1903, 19734, 577, 310]
# z_base_tok:  577
# y_base_tok:  1903
# x_base_tok:  1384
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('11', '6', '2')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 655, 19734, 884, 19734, 854, 310, 337, 15, 380, 906, 273, 1903, 19734, 721, 19734, 374, 310]
# z_base_tok:  374
# y_base_tok:  721
# x_base_tok:  1903
# res base: 6
# res base wo whitespace:
# res base with prefix: a 6
# res base tok: ['a', 'Ġ6']
# operands_base:  ('13', '5', '2')
# x_base_tok:  ['Ġ13']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 1283, 19734, 577, 19734, 721, 310, 854, 15, 380, 906, 273, 2145, 19734, 608, 19734, 374, 310]
# z_base_tok:  374
# y_base_tok:  608
# x_base_tok:  2145
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '2', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 374, 475, 495, 475, 374, 426, 1249, 15, 380, 906, 273, 374, 475, 374, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '2', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 577, 475, 374, 475, 374, 426, 1668, 15, 380, 906, 273, 374, 475, 374, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '2', '3')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 577, 475, 374, 475, 374, 426, 1668, 15, 380, 906, 273, 495, 475, 374, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  495
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('3', '2', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 495, 426, 1249, 15, 380, 906, 273, 495, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  495
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '3', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 374, 426, 854, 15, 380, 906, 273, 374, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 495, 426, 1249, 15, 380, 906, 273, 495, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '2', '3')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 495, 475, 374, 475, 374, 426, 1249, 15, 380, 906, 273, 495, 475, 374, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  495
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '3', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 475, 495, 475, 374, 426, 1283, 15, 380, 906, 273, 374, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  374
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('4', '2', '2')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 495, 475, 495, 426, 1283, 15, 380, 906, 273, 577, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  577
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 495, 426, 1249, 15, 380, 906, 273, 495, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '2', '4')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 495, 426, 1249, 15, 380, 906, 273, 374, 475, 374, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('2', '3', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 495, 475, 495, 475, 374, 426, 1283, 15, 380, 906, 273, 374, 475, 495, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  495
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '3', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 577, 426, 1668, 15, 380, 906, 273, 374, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 495, 426, 1249, 15, 380, 906, 273, 495, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '2', '4')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 495, 475, 495, 475, 374, 426, 1283, 15, 380, 906, 273, 374, 475, 374, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 475, 374, 475, 495, 426, 1283, 15, 380, 906, 273, 495, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('4', '2', '2')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 475, 495, 475, 374, 426, 1283, 15, 380, 906, 273, 577, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  577
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '2', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 374, 475, 495, 475, 374, 426, 1249, 15, 380, 906, 273, 374, 475, 374, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  374
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('4', '2', '2')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 475, 374, 475, 374, 426, 1249, 15, 380, 906, 273, 577, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  577
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '4', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 475, 495, 475, 374, 426, 1283, 15, 380, 906, 273, 374, 475, 577, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  577
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '2', '3')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 495, 426, 1249, 15, 380, 906, 273, 495, 475, 374, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  495
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '2', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 577, 475, 374, 475, 374, 426, 1668, 15, 380, 906, 273, 374, 475, 374, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  374
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '2', '4')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 495, 475, 374, 475, 374, 426, 1249, 15, 380, 906, 273, 374, 475, 374, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '3', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 495, 426, 1249, 15, 380, 906, 273, 374, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '3', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 577, 426, 1668, 15, 380, 906, 273, 374, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 475, 495, 475, 374, 426, 1283, 15, 380, 906, 273, 495, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('4', '2', '2')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 495, 475, 495, 426, 1283, 15, 380, 906, 273, 577, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  577
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('4', '2', '2')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 374, 475, 374, 426, 854, 15, 380, 906, 273, 577, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  577
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('2', '3', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 495, 475, 374, 475, 495, 426, 1283, 15, 380, 906, 273, 374, 475, 495, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  495
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '3', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 475, 495, 475, 374, 426, 1249, 15, 380, 906, 273, 374, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 2069, 374, 2069, 374, 426, 854, 15, 380, 906, 273, 495, 2069, 495, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 2069, 495, 2069, 495, 426, 1283, 15, 380, 906, 273, 495, 2069, 495, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 2069, 577, 2069, 374, 426, 1668, 15, 380, 906, 273, 495, 2069, 495, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('2', '3', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 577, 2069, 374, 2069, 374, 426, 1668, 15, 380, 906, 273, 374, 2069, 495, 2069, 495, 426]
# z_base_tok:  495
# y_base_tok:  495
# x_base_tok:  374
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '4', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 2069, 495, 2069, 374, 426, 1283, 15, 380, 906, 273, 374, 2069, 577, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  577
# x_base_tok:  374
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '2', '4')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 374, 2069, 374, 2069, 495, 426, 1249, 15, 380, 906, 273, 374, 2069, 374, 2069, 577, 426]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  374
# res base: 8
# res base wo whitespace:
# res base with prefix: a 8
# res base tok: ['a', 'Ġ8']
# operands_base:  ('2', '2', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 2069, 495, 2069, 374, 426, 1249, 15, 380, 906, 273, 374, 2069, 374, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 2069, 495, 2069, 374, 426, 1249, 15, 380, 906, 273, 495, 2069, 495, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('3', '2', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 2069, 577, 2069, 374, 426, 1668, 15, 380, 906, 273, 495, 2069, 374, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  495
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '3', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 577, 2069, 374, 2069, 374, 426, 1668, 15, 380, 906, 273, 374, 2069, 495, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '3', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 2069, 495, 2069, 495, 426, 1283, 15, 380, 906, 273, 374, 2069, 495, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  374
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '4', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 374, 2069, 374, 2069, 577, 426, 1668, 15, 380, 906, 273, 374, 2069, 577, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  577
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 495, 2069, 374, 2069, 495, 426, 1283, 15, 380, 906, 273, 495, 2069, 495, 2069, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '2', '3')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 495, 2069, 374, 2069, 374, 426, 1249, 15, 380, 906, 273, 495, 2069, 374, 2069, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  495
# ...
# base string tok list:  [19, 475, 577, 475, 374, 426, 1668, 15, 577, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  577
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '2', '4')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [19, 475, 495, 475, 495, 426, 1283, 15, 374, 475, 374, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  374
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '4', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ2']
# base string tok list:  [21, 475, 374, 475, 374, 426, 1668, 15, 374, 475, 577, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  577
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [20, 475, 374, 475, 495, 426, 1283, 15, 495, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 8
# res base wo whitespace:
# res base with prefix: a 8
# res base tok: ['a', 'Ġ8']
# operands_base:  ('2', '2', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [19, 475, 374, 475, 495, 426, 1249, 15, 374, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('2', '3', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ3']
# base string tok list:  [19, 475, 495, 475, 374, 426, 1249, 15, 374, 475, 495, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  495
# x_base_tok:  374
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 210/210 [00:00<00:00, 220.57it/s]
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '3', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [20, 475, 495, 475, 374, 426, 1283, 15, 495, 475, 495, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '4', '2')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ4']
# z_base_tok:  ['Ġ2']
# base string tok list:  [19, 475, 495, 475, 495, 426, 1283, 15, 374, 475, 577, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  577
# x_base_tok:  374
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '2', '4')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [21, 475, 374, 475, 374, 426, 1668, 15, 374, 475, 374, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('3', '2', '2')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ2']
# base string tok list:  [20, 475, 374, 475, 495, 426, 1283, 15, 495, 475, 374, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  374
# x_base_tok:  495
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('2', '2', '4')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ4']
# base string tok list:  [19, 475, 495, 475, 495, 426, 1283, 15, 374, 475, 374, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  374
# x_base_tok:  374
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('2', '3', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ3']
# base string tok list:  [19, 475, 374, 475, 495, 426, 1249, 15, 374, 475, 495, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  495
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('2', '2', '3')
# x_base_tok:  ['Ġ2']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ3']
# base string tok list:  [21, 475, 374, 475, 374, 426, 1668, 15, 374, 475, 374, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  374
# x_base_tok:  374
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('15', '14', '12')
# x_base_tok:  ['Ġ15']
# y_base_tok:  ['Ġ14']
# z_base_tok:  ['Ġ12']
# base string tok list:  [510, 906, 273, 313, 1458, 428, 1638, 2387, 475, 898, 426, 898, 15, 380, 906, 273, 313, 1458, 428, 1638, 2387, 475, 1249, 426]
# z_base_tok:  1249
# y_base_tok:  1638
# x_base_tok:  1458
# res base: 2
# res base wo whitespace:
# res base with prefix: a 2
# res base tok: ['a', 'Ġ2']
# operands_base:  ('19', '18', '2')
# x_base_tok:  ['Ġ19']
# y_base_tok:  ['Ġ18']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 313, 854, 428, 818, 2387, 475, 854, 426, 854, 15, 380, 906, 273, 313, 655, 428, 1283, 2387, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  1283
# x_base_tok:  655
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('13', '10', '4')
# x_base_tok:  ['Ġ13']
# y_base_tok:  ['Ġ10']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 313, 1458, 428, 1638, 2387, 475, 1283, 426, 1283, 15, 380, 906, 273, 313, 2145, 428, 884, 2387, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  884
# x_base_tok:  2145
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('6', '5', '3')
# x_base_tok:  ['Ġ6']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 313, 1283, 428, 1722, 2387, 475, 721, 426, 721, 15, 380, 906, 273, 313, 721, 428, 608, 2387, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  608
# x_base_tok:  721
# res base: 3
# res base wo whitespace:
# res base with prefix: a 3
# res base tok: ['a', 'Ġ3']
# operands_base:  ('8', '7', '3')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 313, 884, 428, 854, 2387, 475, 495, 426, 721, 15, 380, 906, 273, 313, 854, 428, 818, 2387, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  818
# x_base_tok:  854
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('20', '19', '16')
# x_base_tok:  ['Ġ20']
# y_base_tok:  ['Ġ19']
# z_base_tok:  ['Ġ16']
# base string tok list:  [510, 906, 273, 313, 495, 428, 374, 2387, 475, 1668, 426, 1668, 15, 380, 906, 273, 313, 1384, 428, 655, 2387, 475, 1668, 426]
# z_base_tok:  1668
# y_base_tok:  655
# x_base_tok:  1384
# res base: 10
# res base wo whitespace: 0
# res base with prefix: a 10
# res base tok: ['a', 'Ġ10']
# operands_base:  ('4', '3', '10')
# x_base_tok:  ['Ġ4']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ10']
# base string tok list:  [510, 906, 273, 313, 608, 428, 374, 2387, 475, 495, 426, 898, 15, 380, 906, 273, 313, 577, 428, 495, 2387, 475, 884, 426]
# z_base_tok:  884
# y_base_tok:  495
# x_base_tok:  577
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('18', '14', '4')
# x_base_tok:  ['Ġ18']
# y_base_tok:  ['Ġ14']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 313, 1384, 428, 1458, 2387, 475, 374, 426, 884, 15, 380, 906, 273, 313, 1283, 428, 1638, 2387, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  1638
# x_base_tok:  1283
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('6', '5', '14')
# x_base_tok:  ['Ġ6']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ14']
# base string tok list:  [510, 906, 273, 313, 1384, 428, 655, 2387, 475, 721, 426, 721, 15, 380, 906, 273, 313, 721, 428, 608, 2387, 475, 1638, 426]
# z_base_tok:  1638
# y_base_tok:  608
# x_base_tok:  721
# res base: 4
# res base wo whitespace:
# res base with prefix: a 4
# res base tok: ['a', 'Ġ4']
# operands_base:  ('10', '9', '4')
# x_base_tok:  ['Ġ10']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ4']
# base string tok list:  [510, 906, 273, 313, 1668, 428, 2145, 2387, 475, 374, 426, 721, 15, 380, 906, 273, 313, 884, 428, 898, 2387, 475, 577, 426]
# z_base_tok:  577
# y_base_tok:  898
# x_base_tok:  884
# res base: 2
# res base wo whitespace:
# res base with prefix: a 2
# res base tok: ['a', 'Ġ2']
# operands_base:  ('13', '12', '2')
# x_base_tok:  ['Ġ13']
# y_base_tok:  ['Ġ12']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 313, 898, 428, 854, 2387, 475, 898, 426, 898, 15, 380, 906, 273, 313, 2145, 428, 1249, 2387, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  1249
# x_base_tok:  2145
# res base: 10
# res base wo whitespace: 0
# res base with prefix: a 10
# res base tok: ['a', 'Ġ10']
# operands_base:  ('19', '17', '5')
# x_base_tok:  ['Ġ19']
# y_base_tok:  ['Ġ17']
# z_base_tok:  ['Ġ5']
# base string tok list:  [510, 906, 273, 313, 884, 428, 898, 2387, 475, 1283, 426, 1283, 15, 380, 906, 273, 313, 655, 428, 1722, 2387, 475, 608, 426]
# z_base_tok:  608
# y_base_tok:  1722
# x_base_tok:  655
# res base: 6
# res base wo whitespace:
# res base with prefix: a 6
# res base tok: ['a', 'Ġ6']
# operands_base:  ('8', '7', '6')
# x_base_tok:  ['Ġ8']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ6']
# base string tok list:  [510, 906, 273, 313, 854, 428, 721, 2387, 475, 495, 426, 721, 15, 380, 906, 273, 313, 854, 428, 818, 2387, 475, 721, 426]
# z_base_tok:  721
# y_base_tok:  818
# x_base_tok:  854
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('3', '2', '18')
# x_base_tok:  ['Ġ3']
# y_base_tok:  ['Ġ2']
# z_base_tok:  ['Ġ18']
# base string tok list:  [510, 906, 273, 313, 1668, 428, 1638, 2387, 475, 818, 426, 1638, 15, 380, 906, 273, 313, 495, 428, 374, 2387, 475, 1283, 426]
# z_base_tok:  1283
# y_base_tok:  374
# x_base_tok:  495
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('11', '9', '6')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ6']
# base string tok list:  [510, 906, 273, 313, 1903, 428, 854, 2387, 475, 608, 426, 1458, 15, 380, 906, 273, 313, 1903, 428, 898, 2387, 475, 721, 426]
# z_base_tok:  721
# y_base_tok:  898
# x_base_tok:  1903
# res base: 17
# res base wo whitespace: 7
# res base with prefix: a 17
# res base tok: ['a', 'Ġ17']
# operands_base:  ('10', '9', '17')
# x_base_tok:  ['Ġ10']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ17']
# base string tok list:  [510, 906, 273, 313, 1668, 428, 1458, 2387, 475, 577, 426, 577, 15, 380, 906, 273, 313, 884, 428, 898, 2387, 475, 1722, 426]
# z_base_tok:  1722
# y_base_tok:  898
# x_base_tok:  884
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('13', '7', '2')
# x_base_tok:  ['Ġ13']
# y_base_tok:  ['Ġ7']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 313, 577, 428, 374, 2387, 475, 495, 426, 721, 15, 380, 906, 273, 313, 2145, 428, 818, 2387, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  818
# x_base_tok:  2145
# res base: 6
# res base wo whitespace:
# res base with prefix: a 6
# res base tok: ['a', 'Ġ6']
# operands_base:  ('15', '12', '2')
# x_base_tok:  ['Ġ15']
# y_base_tok:  ['Ġ12']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 313, 2145, 428, 1249, 2387, 475, 854, 426, 854, 15, 380, 906, 273, 313, 1458, 428, 1249, 2387, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  1249
# x_base_tok:  1458
# res base: 6
# res base wo whitespace:
# res base with prefix: a 6
# res base tok: ['a', 'Ġ6']
# operands_base:  ('15', '14', '6')
# x_base_tok:  ['Ġ15']
# y_base_tok:  ['Ġ14']
# z_base_tok:  ['Ġ6']
# base string tok list:  [510, 906, 273, 313, 721, 428, 495, 2387, 475, 495, 426, 898, 15, 380, 906, 273, 313, 1458, 428, 1638, 2387, 475, 721, 426]
# z_base_tok:  721
# y_base_tok:  1638
# x_base_tok:  1458
# res base: 14
# res base wo whitespace: 4
# res base with prefix: a 14
# res base tok: ['a', 'Ġ14']
# operands_base:  ('11', '10', '14')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ10']
# z_base_tok:  ['Ġ14']
# base string tok list:  [510, 906, 273, 313, 1903, 428, 884, 2387, 475, 1458, 426, 1458, 15, 380, 906, 273, 313, 1903, 428, 884, 2387, 475, 1638, 426]
# z_base_tok:  1638
# y_base_tok:  884
# x_base_tok:  1903
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('19', '15', '3')
# x_base_tok:  ['Ġ19']
# y_base_tok:  ['Ġ15']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 313, 721, 428, 608, 2387, 475, 374, 426, 374, 15, 380, 906, 273, 313, 655, 428, 1458, 2387, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  1458
# x_base_tok:  655
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('11', '3', '2')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ3']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 313, 898, 428, 854, 2387, 475, 1249, 426, 1249, 15, 380, 906, 273, 313, 1903, 428, 495, 2387, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  495
# x_base_tok:  1903
# res base: 15
# res base wo whitespace: 5
# res base with prefix: a 15
# res base tok: ['a', 'Ġ15']
# operands_base:  ('14', '11', '5')
# x_base_tok:  ['Ġ14']
# y_base_tok:  ['Ġ11']
# z_base_tok:  ['Ġ5']
# base string tok list:  [510, 906, 273, 313, 1668, 428, 854, 2387, 475, 374, 426, 1668, 15, 380, 906, 273, 313, 1638, 428, 1903, 2387, 475, 608, 426]
# z_base_tok:  608
# y_base_tok:  1903
# x_base_tok:  1638
# res base: 16
# res base wo whitespace: 6
# res base with prefix: a 16
# res base tok: ['a', 'Ġ16']
# operands_base:  ('11', '10', '16')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ10']
# z_base_tok:  ['Ġ16']
# base string tok list:  [510, 906, 273, 313, 1249, 428, 884, 2387, 475, 374, 426, 577, 15, 380, 906, 273, 313, 1903, 428, 884, 2387, 475, 1668, 426]
# z_base_tok:  1668
# y_base_tok:  884
# x_base_tok:  1903
# res base: 4
# res base wo whitespace:
# res base with prefix: a 4
# res base tok: ['a', 'Ġ4']
# operands_base:  ('19', '17', '2')
# x_base_tok:  ['Ġ19']
# y_base_tok:  ['Ġ17']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 313, 818, 428, 721, 2387, 475, 1903, 426, 1903, 15, 380, 906, 273, 313, 655, 428, 1722, 2387, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  1722
# x_base_tok:  655
# res base: 6
# res base wo whitespace:
# res base with prefix: a 6
# res base tok: ['a', 'Ġ6']
# operands_base:  ('9', '6', '2')
# x_base_tok:  ['Ġ9']
# y_base_tok:  ['Ġ6']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 313, 1458, 428, 2145, 2387, 475, 374, 426, 577, 15, 380, 906, 273, 313, 898, 428, 721, 2387, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  721
# x_base_tok:  898
# res base: 12
# res base wo whitespace: 2
# res base with prefix: a 12
# res base tok: ['a', 'Ġ12']
# operands_base:  ('13', '9', '3')
# x_base_tok:  ['Ġ13']
# y_base_tok:  ['Ġ9']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 313, 1668, 428, 1638, 2387, 475, 898, 426, 1283, 15, 380, 906, 273, 313, 2145, 428, 898, 2387, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  898
# x_base_tok:  2145
# res base: 2
# res base wo whitespace:
# res base with prefix: a 2
# res base tok: ['a', 'Ġ2']
# operands_base:  ('9', '8', '2')
# x_base_tok:  ['Ġ9']
# y_base_tok:  ['Ġ8']
# z_base_tok:  ['Ġ2']
# base string tok list:  [510, 906, 273, 313, 1283, 428, 884, 2387, 475, 374, 426, 1668, 15, 380, 906, 273, 313, 898, 428, 854, 2387, 475, 374, 426]
# z_base_tok:  374
# y_base_tok:  854
# x_base_tok:  898
# res base: 18
# res base wo whitespace: 8
# res base with prefix: a 18
# res base tok: ['a', 'Ġ18']
# operands_base:  ('11', '5', '3')
# x_base_tok:  ['Ġ11']
# y_base_tok:  ['Ġ5']
# z_base_tok:  ['Ġ3']
# base string tok list:  [510, 906, 273, 313, 854, 428, 818, 2387, 475, 884, 426, 884, 15, 380, 906, 273, 313, 1903, 428, 608, 2387, 475, 495, 426]
# z_base_tok:  495
# y_base_tok:  608
# x_base_tok:  1903
# res base: 9
# res base wo whitespace:
# res base with prefix: a 9
# res base tok: ['a', 'Ġ9']
# operands_base:  ('16', '15', '9')
# x_base_tok:  ['Ġ16']
# y_base_tok:  ['Ġ15']
# z_base_tok:  ['Ġ9']
# base string tok list:  [510, 906, 273, 313, 818, 428, 577, 2387, 475, 721, 426, 1283, 15, 380, 906, 273, 313, 1668, 428, 1458, 2387, 475, 898, 426]
# z_base_tok:  898
# y_base_tok:  1458
# x_base_tok:  1668

# %%
example_prompt = intervention_list[0].few_shots + intervention_list[0].base_string
example_answer = ' 11'
utils.test_prompt(example_prompt, example_answer, model, prepend_bos=False)
# Out:
# Tokenized prompt: ['4', ' +', ' 4', ' +', ' 6', ' =', ' 14', '.', ' 3', ' +', ' 5', ' +', ' 6', ' =']
# Tokenized answer: [' 11']
# Performance on answer token:
# Rank: 18       Logit: 12.88 Prob:  0.85% Token: | 11|
# Top 0th token. Logit: 16.38 Prob: 28.12% Token: | 14|
# Top 1th token. Logit: 15.62 Prob: 13.28% Token: | 16|
# Top 2th token. Logit: 15.12 Prob:  8.06% Token: | 18|
# Top 3th token. Logit: 14.69 Prob:  5.22% Token: | 4|
# Top 4th token. Logit: 14.50 Prob:  4.32% Token: | 19|
# Top 5th token. Logit: 14.38 Prob:  3.81% Token: | 20|
# Top 6th token. Logit: 14.31 Prob:  3.59% Token: | 17|
# Top 7th token. Logit: 14.25 Prob:  3.37% Token: | 3|
# Top 8th token. Logit: 14.25 Prob:  3.37% Token: | 2|
# Top 9th token. Logit: 14.19 Prob:  3.17% Token: | 13|
# Ranks of the answer tokens: [(' 11', 18)]

# %%
prompt = 'Perform the arithmetic calculations based on the sequence of numbers and operators provided. '
prompt_tokenized = tokenizer(prompt, add_special_tokens=False, return_tensors='pt')['input_ids']
tokenizer.decode(prompt_tokenized[0])
# Out:
# 'Perform the arithmetic calculations based on the sequence of numbers and operators provided. '

# %% [markdown]
# Let's filter only those instances which are correct on the prompt with ICD and incorrect with a prompt without

# %%
len(intervention_list)
# Out:
# 210

# %%
corr_intervention_list = []
for item in intervention_list:
    input_id_base = item.base_string_tok.to(model.cfg.device)
    input_id_alt = item.alt_string_tok.to(model.cfg.device)
    
    # print(tokenizer.decode(input_id_base[0].tolist()))
    # print(tokenizer.decode(input_id_alt[0].tolist()))
    
    input_id_base = torch.cat((prompt_tokenized.to(model.cfg.device), input_id_base), dim=1)
    input_id_alt = torch.cat((prompt_tokenized.to(model.cfg.device), input_id_alt), dim=1)

    output_base = model.generate(input_id_base, max_new_tokens=1, do_sample=False)[0, -1].cpu().numpy()
    output_alt = model.generate(input_id_alt, max_new_tokens=1, do_sample=False)[0, -1].cpu().numpy()
    corr_tok = item.res_base_tok[0]

    item.set_predicted_alt_result(pred_alt_string=tokenizer.decode([output_alt]), pred_res_alt_tok=output_alt)
    if output_base == corr_tok and output_alt != corr_tok:
        corr_intervention_list.append(item)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
len(corr_intervention_list)
# Out:
# 61

# %%
for item in corr_intervention_list:
    print(tokenizer.decode(item.base_string_tok[0].tolist()))
    print(tokenizer.decode(item.alt_string_tok[0].tolist()))
# Out:
# 4 + 2 + 8 = 14. 8 + 2 + 2 =
#        <|endoftext|> 8 + 2 + 2 =
# 5 + 4 + 2 = 11. 8 + 6 + 5 =
#        <|endoftext|> 8 + 6 + 5 =
# 9 + 2 + 2 = 13. 6 + 2 + 3 =
#        <|endoftext|> 6 + 2 + 3 =
# 4 + 6 + 8 = 18. 2 + 9 + 6 =
#        <|endoftext|> 2 + 9 + 6 =
# 3 + 3 + 7 = 13. 4 + 9 + 5 =
#        <|endoftext|> 4 + 9 + 5 =
# 9 + 2 + 7 = 18. 2 + 10 + 3 =
#        <|endoftext|> 2 + 10 + 3 =
# 6 + 2 + 5 = 13. 11 + 3 + 2 =
#        <|endoftext|> 11 + 3 + 2 =
# 5 + 7 + 6 = 18. 11 + 2 + 6 =
#        <|endoftext|> 11 + 2 + 6 =
# 5 + 12 + 2 = 19. 4 + 6 + 6 =
#        <|endoftext|> 4 + 6 + 6 =
# 4 + 4 + 4 = 12. 8 + 7 + 4 =
#        <|endoftext|> 8 + 7 + 4 =
# 2 + 5 + 12 = 19. 5 + 7 + 3 =
#        <|endoftext|> 5 + 7 + 3 =
# 7 + 5 + 5 = 17. 11 + 3 + 2 =
#        <|endoftext|> 11 + 3 + 2 =
# 4 + 5 + 8 = 17. 6 + 7 + 5 =
#        <|endoftext|> 6 + 7 + 5 =
# 10 + 2 + 2 = 14. 4 + 10 + 2 =
#        <|endoftext|> 4 + 10 + 2 =
# The result of 3 + 4 + 6 = 13. The result of 8 + 3 + 8 =
#           <|endoftext|> The result of 8 + 3 + 8 =
# The result of 2 + 13 + 3 = 18. The result of 5 + 7 + 5 =
#           <|endoftext|> The result of 5 + 7 + 5 =
# The result of 5 + 7 + 5 = 17. The result of 9 + 6 + 2 =
#           <|endoftext|> The result of 9 + 6 + 2 =
# The result of 5 + 5 + 6 = 16. The result of 3 + 4 + 9 =
#           <|endoftext|> The result of 3 + 4 + 9 =
# The result of 5 + 7 + 3 = 15. The result of 10 + 2 + 6 =
#           <|endoftext|> The result of 10 + 2 + 6 =
# The result of 3 + 5 + 6 = 14. The result of 10 + 4 + 2 =
#           <|endoftext|> The result of 10 + 4 + 2 =
# The result of 12 minus 6 minus 5 is 1. The result of 18 minus 3 minus 8 is
#           <|endoftext|> The result of 18 minus 3 minus 8 is
# The result of 18 minus 5 minus 2 is 11. The result of 16 minus 10 minus 5 is
#           <|endoftext|> The result of 16 minus 10 minus 5 is
# The result of 15 minus 3 minus 4 is 8. The result of 20 minus 5 minus 2 is
#           <|endoftext|> The result of 20 minus 5 minus 2 is
# The result of 19 minus 10 minus 8 is 1. The result of 11 minus 6 minus 2 is
#           <|endoftext|> The result of 11 minus 6 minus 2 is
# The result of 2 * 2 * 3 = 12. The result of 2 * 2 * 4 =
#           <|endoftext|> The result of 2 * 2 * 4 =
# The result of 3 * 3 * 2 = 18. The result of 2 * 2 * 4 =
#           <|endoftext|> The result of 2 * 2 * 4 =
# The result of 3 * 3 * 2 = 18. The result of 2 * 4 * 2 =
#           <|endoftext|> The result of 2 * 4 * 2 =
# The result of 3 * 2 * 2 = 12. The result of 2 * 2 * 4 =
#           <|endoftext|> The result of 2 * 2 * 4 =
# The result of 3 times 3 times 2 = 18. The result of 2 times 4 times 2 =
#           <|endoftext|> The result of 2 times 4 times 2 =
# The result of 2 times 4 times 2 = 16. The result of 2 times 4 times 2 =
#           <|endoftext|> The result of 2 times 4 times 2 =
# 2 * 3 * 3 = 18. 3 * 2 * 2 =
#        <|endoftext|> 3 * 2 * 2 =
# 2 * 2 * 3 = 12. 2 * 2 * 4 =
#        <|endoftext|> 2 * 2 * 4 =
# 2 * 3 * 3 = 18. 2 * 2 * 4 =
#        <|endoftext|> 2 * 2 * 4 =
# 2 * 4 * 2 = 16. 3 * 3 * 2 =
#        <|endoftext|> 3 * 3 * 2 =
# 2 * 3 * 3 = 18. 3 * 2 * 2 =
#        <|endoftext|> 3 * 2 * 2 =
# 2 * 2 * 4 = 16. 2 * 3 * 3 =
#        <|endoftext|> 2 * 3 * 3 =
# 3 * 2 * 2 = 12. 2 * 2 * 4 =
#        <|endoftext|> 2 * 2 * 4 =
# 3 * 3 * 2 = 18. 2 * 3 * 3 =
#        <|endoftext|> 2 * 3 * 3 =
# 2 * 2 * 3 = 12. 2 * 3 * 3 =
#        <|endoftext|> 2 * 3 * 3 =
# 2 * 3 * 3 = 18. 2 * 2 * 4 =
#        <|endoftext|> 2 * 2 * 4 =
# 4 * 2 * 2 = 16. 2 * 4 * 2 =
#        <|endoftext|> 2 * 4 * 2 =
# 3 * 2 * 3 = 18. 3 * 3 * 2 =
#        <|endoftext|> 3 * 3 * 2 =
# 2 * 3 * 2 = 12. 2 * 3 * 3 =
#        <|endoftext|> 2 * 3 * 3 =
# 3 * 3 * 2 = 18. 3 * 3 * 2 =
#        <|endoftext|> 3 * 3 * 2 =
# 2 * 3 * 3 = 18. 2 * 4 * 2 =
#        <|endoftext|> 2 * 4 * 2 =
# 4 * 2 * 2 = 16. 2 * 2 * 4 =
#        <|endoftext|> 2 * 2 * 4 =
# 3 * 2 * 3 = 18. 3 * 2 * 2 =
#        <|endoftext|> 3 * 2 * 2 =
# 2 * 3 * 3 = 18. 2 * 2 * 4 =
#        <|endoftext|> 2 * 2 * 4 =
# 2 * 2 * 3 = 12. 2 * 3 * 3 =
#        <|endoftext|> 2 * 3 * 3 =
# The result of ( 15 - 14 ) * 9 = 9. The result of ( 15 - 14 ) * 12 =
#             <|endoftext|> The result of ( 15 - 14 ) * 12 =
# The result of ( 8 - 7 ) * 8 = 8. The result of ( 19 - 18 ) * 2 =
#             <|endoftext|> The result of ( 19 - 18 ) * 2 =
# The result of ( 18 - 17 ) * 6 = 6. The result of ( 6 - 5 ) * 3 =
#             <|endoftext|> The result of ( 6 - 5 ) * 3 =
# The result of ( 3 - 2 ) * 16 = 16. The result of ( 20 - 19 ) * 16 =
#             <|endoftext|> The result of ( 20 - 19 ) * 16 =
# The result of ( 20 - 15 ) * 2 = 10. The result of ( 18 - 14 ) * 4 =
#             <|endoftext|> The result of ( 18 - 14 ) * 4 =
# The result of ( 20 - 19 ) * 6 = 6. The result of ( 6 - 5 ) * 14 =
#             <|endoftext|> The result of ( 6 - 5 ) * 14 =
# The result of ( 9 - 8 ) * 9 = 9. The result of ( 13 - 12 ) * 2 =
#             <|endoftext|> The result of ( 13 - 12 ) * 2 =
# The result of ( 8 - 6 ) * 3 = 6. The result of ( 8 - 7 ) * 6 =
#             <|endoftext|> The result of ( 8 - 7 ) * 6 =
# The result of ( 16 - 14 ) * 7 = 14. The result of ( 3 - 2 ) * 18 =
#             <|endoftext|> The result of ( 3 - 2 ) * 18 =
# The result of ( 16 - 15 ) * 4 = 4. The result of ( 10 - 9 ) * 17 =
#             <|endoftext|> The result of ( 10 - 9 ) * 17 =
# The result of ( 11 - 10 ) * 15 = 15. The result of ( 11 - 10 ) * 14 =
#             <|endoftext|> The result of ( 11 - 10 ) * 14 =
# The result of ( 12 - 10 ) * 2 = 4. The result of ( 11 - 10 ) * 16 =
#             <|endoftext|> The result of ( 11 - 10 ) * 16 =

# %%
# torch.save(corr_intervention_list, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/my_perturbations_data_pythia_12b/base_data_arabic_pythia_12b.pkl')

# %%
corr_intervention_list = torch.load('./data/my_perturbations_data_pythia_12b/base_data_arabic_pythia_12b.pkl', weights_only=False)

# %% [markdown]
# Let's now plot patching results for all considered pairs

# %%
def get_logit_diff(logits, answer_token_indices):
    if len(logits.shape)==3:
        # Get final logits only
        logits = logits[:, -1, :]
    correct_logits = logits.gather(1, answer_token_indices[:, 0].unsqueeze(1))
    incorrect_logits = logits.gather(1, answer_token_indices[:, 1].unsqueeze(1))
    return (correct_logits - incorrect_logits).mean()

# %%
def get_patched_result(item, activation_name='resid_pre'):
    clean_logits, clean_cache = model.run_with_cache(item.base_string_tok)
    corrupted_logits = model(item.alt_string_tok)

    answer_token_indices = torch.tensor([[item.res_base_tok[0], item.pred_res_alt_tok]]).to(model.cfg.device)

    clean_logit_diff = get_logit_diff(clean_logits, answer_token_indices).cpu()
    corrupted_logit_diff = get_logit_diff(corrupted_logits, answer_token_indices).cpu()

    # def metric(logits, answer_token_indices=answer_token_indices):
    #     return (get_logit_diff(logits, answer_token_indices) - corrupted_logit_diff) / torch.abs(clean_logit_diff - corrupted_logit_diff)
    metric = partial(get_logit_diff, answer_token_indices=answer_token_indices)
    
    if activation_name == 'resid_pre':
        patched_logit_diff = patching.get_act_patch_resid_pre(model, item.alt_string_tok.to(model.cfg.device), clean_cache, metric).cpu()
    elif activation_name == 'attn_layer':
        patched_logit_diff = patching.get_act_patch_attn_out(model, item.alt_string_tok.to(model.cfg.device), clean_cache, metric).cpu()
    elif activation_name == 'mlp':
        patched_logit_diff = patching.get_act_patch_mlp_out(model, item.alt_string_tok.to(model.cfg.device), clean_cache, metric).cpu()
    elif activation_name == 'head':
        patched_logit_diff = patching.get_act_patch_attn_head_out_all_pos(model, item.alt_string_tok.to(model.cfg.device), clean_cache, metric).cpu()

    return patched_logit_diff, clean_logit_diff, corrupted_logit_diff

# %%
def get_patched_result_prompt_preceeding(item, activation_name='resid_pre'):
    input_id_base = item.base_string_tok.to(model.cfg.device)
    input_id_alt = item.alt_string_tok.to(model.cfg.device)
    input_id_base = torch.cat((prompt_tokenized.to(model.cfg.device), input_id_base), dim=1)
    input_id_alt = torch.cat((prompt_tokenized.to(model.cfg.device), input_id_alt), dim=1)
    
    print(tokenizer.decode(input_id_base[0].tolist()))
    print(tokenizer.decode(input_id_alt[0].tolist()))
    
    clean_logits, clean_cache = model.run_with_cache(input_id_base)
    corrupted_logits = model(input_id_alt)

    answer_token_indices = torch.tensor([[item.res_base_tok[0], item.pred_res_alt_tok]]).to(model.cfg.device)

    clean_logit_diff = get_logit_diff(clean_logits, answer_token_indices).cpu()
    corrupted_logit_diff = get_logit_diff(corrupted_logits, answer_token_indices).cpu()

    # def metric(logits, answer_token_indices=answer_token_indices):
    #     return (get_logit_diff(logits, answer_token_indices) - corrupted_logit_diff) / torch.abs(clean_logit_diff - corrupted_logit_diff)
    metric = partial(get_logit_diff, answer_token_indices=answer_token_indices)
    
    if activation_name == 'resid_pre':
        patched_logit_diff = patching.get_act_patch_resid_pre(model, input_id_alt, clean_cache, metric).cpu()
    elif activation_name == 'attn_layer':
        patched_logit_diff = patching.get_act_patch_attn_out(model, input_id_alt, clean_cache, metric).cpu()
    elif activation_name == 'mlp':
        patched_logit_diff = patching.get_act_patch_mlp_out(model, input_id_alt, clean_cache, metric).cpu()
    elif activation_name == 'head':
        patched_logit_diff = patching.get_act_patch_attn_head_out_all_pos(model, input_id_alt, clean_cache, metric).cpu()

    return patched_logit_diff, clean_logit_diff, corrupted_logit_diff

# %%
labels = ['operand_1', 'operator_1', 'operand_2', 'operator_2', 'operand_3', 'eq', 'res', 'operand_1', 'operator_1', 'operand_2', 'operator_2', 'operand_3', 'eq']

# %%
# all_resid_pre_act_patch_results = []
# all_resid_pre_clean_logit_diffs = []
# all_resid_pre_corrupted_logit_diffs = []
# for item in tqdm(corr_intervention_list[:1]):
#     patched_logit_diff, clean_logit_diff, corrupted_logit_diff = get_patched_result(item)
#     all_resid_pre_act_patch_results.append(patched_logit_diff)
#     all_resid_pre_clean_logit_diffs.append(clean_logit_diff)
#     all_resid_pre_corrupted_logit_diffs.append(corrupted_logit_diff)

# %%
all_resid_pre_act_patch_results = []
all_resid_pre_clean_logit_diffs = []
all_resid_pre_corrupted_logit_diffs = []
for item in tqdm(corr_intervention_list):
    patched_logit_diff, clean_logit_diff, corrupted_logit_diff = get_patched_result_prompt_preceeding(item)
    all_resid_pre_act_patch_results.append(patched_logit_diff)
    all_resid_pre_clean_logit_diffs.append(clean_logit_diff)
    all_resid_pre_corrupted_logit_diffs.append(corrupted_logit_diff)
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 6 + 2 + 3 = 11. 4 + 6 + 8 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 4 + 6 + 8 =
# /tmp/ipykernel_2910419/1063455172.py:13: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   answer_token_indices = torch.tensor([[item.res_base_tok[0], item.pred_res_alt_tok]]).to(model.cfg.device)
#   0%|          | 0/1080 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 5
#       3 all_resid_pre_corrupted_logit_diffs = []
#       4 for item in tqdm(corr_intervention_list):
# ----> 5     patched_logit_diff, clean_logit_diff, corrupted_logit_diff = get_patched_result_prompt_preceeding(item)
#       6     all_resid_pre_act_patch_results.append(patched_logit_diff)
#       7     all_resid_pre_clean_logit_diffs.append(clean_logit_diff)
#
# Cell In[17], line 23, in get_patched_result_prompt_preceeding(item, activation_name)
#      20 metric = partial(get_logit_diff, answer_token_indices=answer_token_indices)
#      22 if activation_name == 'resid_pre':
# ---> 23     patched_logit_diff = patching.get_act_patch_resid_pre(model, input_id_alt, clean_cache, metric).cpu()
#      24 elif activation_name == 'attn_layer':
#      25     patched_logit_diff = patching.get_act_patch_attn_out(model, input_id_alt, clean_cache, metric).cpu()
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/transformer_lens/patching.py:218, in generic_activation_patch(model, corrupted_tokens, clean_cache, patching_metric, patch_setter, activation_name, index_axis_names, index_df, return_index_df)
#     211 current_hook = partial(
#     212     patching_hook,
#     213     index=index,
#     214     clean_activation=clean_cache[current_activation_name],
#     215 )
#     217 # Run the model with the patching hook and get the logits!
# --> 218 patched_logits = model.run_with_hooks(
#     219     corrupted_tokens, fwd_hooks=[(current_activation_name, current_hook)]
#     220 )
#     222 # Calculate the patching metric and store
#     223 if flattened_output:
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/transformer_lens/hook_points.py:454, in HookedRootModule.run_with_hooks(self, fwd_hooks, bwd_hooks, reset_hooks_end, clear_contexts, *model_args, **model_kwargs)
#     449     logging.warning(
#     450         "WARNING: Hooks will be reset at the end of run_with_hooks. This removes the backward hooks before a backward pass can occur."
#     451     )
#     453 with self.hooks(fwd_hooks, bwd_hooks, reset_hooks_end, clear_contexts) as hooked_model:
# --> 454     return hooked_model.forward(*model_args, **model_kwargs)
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/transformer_lens/HookedTransformer.py:576, in HookedTransformer.forward(self, input, return_type, loss_per_token, prepend_bos, padding_side, start_at_layer, tokens, shortformer_pos_embed, attention_mask, stop_at_layer, past_kv_cache)
#     571     if shortformer_pos_embed is not None:
#     572         shortformer_pos_embed = shortformer_pos_embed.to(
#     573             devices.get_device_for_block_index(i, self.cfg)
#     574         )
# --> 576     residual = block(
#     577         residual,
#     578         # Cache contains a list of HookedTransformerKeyValueCache objects, one for each
#     579         # block
#     580         past_kv_cache_entry=past_kv_cache[i] if past_kv_cache is not None else None,
#     581         shortformer_pos_embed=shortformer_pos_embed,
#     582         attention_mask=attention_mask,
#     583     )  # [batch, pos, d_model]
#     585 if stop_at_layer is not None:
#     586     # When we stop at an early layer, we end here rather than doing further computation
#     587     return residual
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/transformer_lens/components/transformer_block.py:160, in TransformerBlock.forward(self, resid_pre, shortformer_pos_embed, past_kv_cache_entry, attention_mask)
#     153     key_input = attn_in
#     154     value_input = attn_in
#     156 attn_out = (
#     157     # hook the residual stream states that are used to calculate the
#     158     # queries, keys and values, independently.
#     159     # Then take the layer norm of these inputs, and pass these to the attention module.
# --> 160     self.attn(
#     161         query_input=self.ln1(query_input)
#     162         + (0.0 if shortformer_pos_embed is None else shortformer_pos_embed),
#     163         key_input=self.ln1(key_input)
#     164         + (0.0 if shortformer_pos_embed is None else shortformer_pos_embed),
#     165         value_input=self.ln1(value_input),
#     166         past_kv_cache_entry=past_kv_cache_entry,
#     167         attention_mask=attention_mask,
#     168     )
#     169 )  # [batch, pos, d_model]
#     170 if self.cfg.use_normalization_before_and_after:
#     171     # If we use LayerNorm both before and after, then apply the second LN after the layer
#     172     # and before the hook. We do it before the hook so hook_attn_out captures "that which
#     173     # is added to the residual stream"
#     174     attn_out = self.ln1_post(attn_out)
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/transformer_lens/components/abstract_attention.py:252, in AbstractAttention.forward(self, query_input, key_input, value_input, past_kv_cache_entry, additive_attention_mask, attention_mask, position_bias)
#     249     attn_scores += position_bias
#     250 if self.cfg.attention_dir == "causal":
#     251     # If causal attention, we mask it to only attend backwards. If bidirectional, we don't mask.
# --> 252     attn_scores = self.apply_causal_mask(
#     253         attn_scores, kv_cache_pos_offset, attention_mask
#     254     )  # [batch, head_index, query_pos, key_pos]
#     255 if additive_attention_mask is not None:
#     256     attn_scores += additive_attention_mask
#
# File ~/.conda/envs/icl_mech_interp/lib/python3.9/site-packages/transformer_lens/components/abstract_attention.py:456, in AbstractAttention.apply_causal_mask(self, attn_scores, past_kv_pos_offset, attention_mask)
#     451     raise ValueError(
#     452         f"query_ctx_length {query_ctx_length} + past_kv_pos_offset {past_kv_pos_offset} != key_ctx_length {key_ctx_length} - you likely have a bug."
#     453     )
#     455 # Index back to front to ensure local attention works
# --> 456 final_mask = self.mask[None, None, -query_ctx_length:, -key_ctx_length:]  # [1, 1, pos, pos]
#     457 if attention_mask is not None:
#     458     # Apply a causal mask to the attention scores considering the padding
#     459     einsum_str = "batch head pos offset_pos, batch offset_pos -> batch head pos offset_pos"
#
# KeyboardInterrupt:

# %%
all_resid_pre_act_patch_results_2 = []
all_resid_pre_clean_logit_diffs_2 = []
all_resid_pre_corrupted_logit_diffs_2 = []
for item in tqdm(corr_intervention_list[52:]):
    patched_logit_diff, clean_logit_diff, corrupted_logit_diff = get_patched_result_prompt_preceeding(item)
    all_resid_pre_act_patch_results_2.append(patched_logit_diff)
    all_resid_pre_clean_logit_diffs_2.append(clean_logit_diff)
    all_resid_pre_corrupted_logit_diffs_2.append(corrupted_logit_diff)
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 * 2 * 3 = 12. The result of 3 * 2 * 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 3 * 2 * 3 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 * 2 * 4 = 16. The result of 2 * 3 * 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 * 3 * 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 3 times 3 times 2 = 18. The result of 2 times 4 times 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 4 times 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 times 3 times 2 = 12. The result of 2 times 2 times 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 2 times 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 times 3 times 2 = 12. The result of 3 times 3 times 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 3 times 3 times 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 4 times 2 times 2 = 16. The result of 2 times 3 times 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 3 times 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 3 times 2 times 3 = 18. The result of 3 times 3 times 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 3 times 3 times 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 3 times 3 times 2 = 18. The result of 2 times 3 times 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 3 times 3 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 times 3 times 2 = 12. The result of 2 times 4 times 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 4 times 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 times 4 times 2 = 16. The result of 2 times 2 times 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 2 times 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 4 times 2 times 2 = 16. The result of 3 times 2 times 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 3 times 2 times 3 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 3 times 2 times 3 = 18. The result of 2 times 2 times 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 2 times 3 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 times 3 times 3 = 18. The result of 2 times 2 times 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 2 times 3 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 times 2 times 2 = 8. The result of 3 times 2 times 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 3 times 2 times 3 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 times 4 times 2 = 16. The result of 2 times 2 times 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 2 times 2 times 2 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of 2 times 2 times 4 = 16. The result of 3 times 2 times 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.           <|endoftext|> The result of 3 times 2 times 3 =
#   0%|          | 0/1296 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 2 * 4 * 2 = 16. 3 * 3 * 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 3 * 3 * 2 =
#   0%|          | 0/1080 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 2 * 2 * 4 = 16. 2 * 3 * 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 2 * 3 * 3 =
#   0%|          | 0/1080 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 3 * 3 * 2 = 18. 2 * 3 * 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 2 * 3 * 3 =
#   0%|          | 0/1080 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 2 * 2 * 3 = 12. 2 * 3 * 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 2 * 3 * 3 =
#   0%|          | 0/1080 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 3 * 2 * 3 = 18. 3 * 3 * 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 3 * 3 * 2 =
#   0%|          | 0/1080 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 2 * 3 * 2 = 12. 2 * 3 * 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 2 * 3 * 3 =
#   0%|          | 0/1080 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 3 * 3 * 2 = 18. 3 * 3 * 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 3 * 3 * 2 =
#   0%|          | 0/1080 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. 2 * 2 * 3 = 12. 2 * 3 * 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.        <|endoftext|> 2 * 3 * 3 =
#   0%|          | 0/1080 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 15 - 14 ) * 9 = 9. The result of ( 15 - 14 ) * 12 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 15 - 14 ) * 12 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 8 - 7 ) * 8 = 8. The result of ( 19 - 18 ) * 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 19 - 18 ) * 2 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 18 - 17 ) * 6 = 6. The result of ( 6 - 5 ) * 3 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 6 - 5 ) * 3 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 3 - 2 ) * 16 = 16. The result of ( 20 - 19 ) * 16 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 20 - 19 ) * 16 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 20 - 15 ) * 2 = 10. The result of ( 18 - 14 ) * 4 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 18 - 14 ) * 4 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 20 - 19 ) * 6 = 6. The result of ( 6 - 5 ) * 14 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 6 - 5 ) * 14 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 9 - 8 ) * 9 = 9. The result of ( 13 - 12 ) * 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 13 - 12 ) * 2 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 8 - 6 ) * 3 = 6. The result of ( 8 - 7 ) * 6 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 8 - 7 ) * 6 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 16 - 14 ) * 7 = 14. The result of ( 3 - 2 ) * 18 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 3 - 2 ) * 18 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 16 - 15 ) * 4 = 4. The result of ( 10 - 9 ) * 17 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 10 - 9 ) * 17 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 11 - 10 ) * 15 = 15. The result of ( 11 - 10 ) * 14 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 11 - 10 ) * 14 =
#   0%|          | 0/1440 [00:00<?, ?it/s]
# Perform the arithmetic calculations based on the sequence of numbers and operators provided. The result of ( 15 - 13 ) * 2 = 4. The result of ( 9 - 6 ) * 2 =
# Perform the arithmetic calculations based on the sequence of numbers and operators provided.             <|endoftext|> The result of ( 9 - 6 ) * 2 =
#   0%|          | 0/1440 [00:00<?, ?it/s]

# %%
all_resid_pre_act_patch_results_all = all_resid_pre_act_patch_results + all_resid_pre_act_patch_results_2
all_resid_pre_clean_logit_diffs_all = all_resid_pre_clean_logit_diffs + all_resid_pre_clean_logit_diffs_2
all_resid_pre_corrupted_logit_diffs_all = all_resid_pre_corrupted_logit_diffs + all_resid_pre_corrupted_logit_diffs_2

# %%
# all_resid_pre_act_patch_results = []
# all_resid_pre_clean_logit_diffs = []
# all_resid_pre_corrupted_logit_diffs = []
# for item in tqdm(corr_intervention_list):
#     patched_logit_diff, clean_logit_diff, corrupted_logit_diff = get_patched_result(item)
#     all_resid_pre_act_patch_results.append(patched_logit_diff)
#     all_resid_pre_clean_logit_diffs.append(clean_logit_diff)
#     all_resid_pre_corrupted_logit_diffs.append(corrupted_logit_diff)

# %%
# torch.save(all_resid_pre_act_patch_results, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/resid_pre_logit_diff_96_samples.pkl')
# torch.save(all_resid_pre_clean_logit_diffs, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/clean_diff_96_samples.pkl')
# torch.save(all_resid_pre_corrupted_logit_diffs, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/corrupted_logit_diff_96_samples.pkl')

# all_resid_pre_act_patch_results = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/resid_pre_logit_diff_96_samples.pkl')
# all_resid_pre_clean_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/clean_diff_96_samples.pkl')
# all_resid_pre_corrupted_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/corrupted_logit_diff_96_samples.pkl')

# %%
def take_operands_and_operators_results(intervention_list, patched_results):
    all_operators = {'+', '-', '*', 'times', 'minus', 'plus'}
    all_equal_signs = {'=', 'is'}
    
    patched_results_operands_and_operators = []
    for idx, item in enumerate(intervention_list[:len(patched_results)]):
        curr_tokens = [tokenizer.decode(token) for token in item.base_string_tok[0]]
        considered_positions = []
        for position, token in enumerate(curr_tokens):
            if token.strip() in all_operators or token.strip() in all_equal_signs or token.strip().isnumeric():
                considered_positions.append(position)
        patched_results_operands_and_operators.append(patched_results[idx][:, considered_positions])
    return patched_results_operands_and_operators

def take_operands_and_operators_results_plus_prompt(intervention_list, patched_results):
    all_operators = {'+', '-', '*', 'times', 'minus', 'plus'}
    all_equal_signs = {'=', 'is'}
    
    patched_results_operands_and_operators = []
    for idx, item in enumerate(intervention_list[:len(patched_results)]):
        curr_tokens = [tokenizer.decode(token) for token in prompt_tokenized[0]] + [tokenizer.decode(token) for token in item.base_string_tok[0]]
        considered_positions = []
        for position, token in enumerate(curr_tokens):
            if token.strip() in all_operators or token.strip() in all_equal_signs or token.strip().isnumeric():
                considered_positions.append(position)
        patched_results_task_prompt_averaged = torch.mean(patched_results[idx][:, range(len(prompt_tokenized[0]))], dim=-1).unsqueeze(1)
        patched_results_operands_and_operators.append(torch.cat((patched_results_task_prompt_averaged, patched_results[idx][:, considered_positions]), dim=1))

    return patched_results_operands_and_operators

# %%
patched_results_operands_operators = take_operands_and_operators_results_plus_prompt(corr_intervention_list, all_resid_pre_act_patch_results_all)

# %%
def compute_macro_mean(patched_results, clean_logit_diffs, corrupted_logit_diffs):
    return (torch.mean(torch.stack(patched_results), dim=0) - torch.tensor(corrupted_logit_diffs).mean()) / (torch.tensor(clean_logit_diffs).mean() - torch.tensor(corrupted_logit_diffs).mean())

def compute_micro_mean(patched_results, clean_logit_diffs, corrupted_logit_diffs):
    # return (torch.mean(torch.stack(patched_results), dim=0) - torch.mean(corrupted_logit_diffs)) / torch.abs(torch.mean(clean_logit_diffs) - torch.mean(corrupted_logit_diffs))
    return torch.mean((torch.stack(patched_results) - torch.tensor(corrupted_logit_diffs)[:, None, None]) / (torch.tensor(clean_logit_diffs)[:, None, None] - torch.tensor(corrupted_logit_diffs)[:, None, None]), dim=0)

def compute_pe(patched_results, clean_logit_diffs, corrupted_logit_diffs):
    return torch.mean(torch.stack(patched_results) - torch.tensor(corrupted_logit_diffs)[:, None, None], dim=0)

# %%
sns.heatmap(
    all_resid_pre_act_patch_results[0]
)
# Out:
# <Axes: >

# %%
all_resid_pre_act_patch_results
# Out:
# [tensor([[-0.3125, -0.3125, -0.3125,  ..., -0.3125, -0.3125, -0.3125],
#          [-0.3125, -0.3125, -0.3125,  ..., -0.2500, -0.3125,  0.0000],
#          [-0.3125, -0.3125, -0.3125,  ...,  0.1875, -0.1250, -0.2500],
#          ...,
#          [-0.3125, -0.3125, -0.3125,  ..., -0.2500, -0.1875,  3.0000],
#          [-0.3125, -0.3125, -0.3125,  ..., -0.2500, -0.1875,  3.0000],
#          [-0.3125, -0.3125, -0.3125,  ..., -0.3125, -0.2500,  3.0625]])]

# %%
all_resid_pre_act_patch_results[0].shape
# Out:
# torch.Size([36, 30])

# %%
sns.heatmap(
        compute_pe(all_resid_pre_act_patch_results, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs).T,
        cmap='Blues',
        vmin=torch.min(compute_pe(all_resid_pre_act_patch_results, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs)),
        vmax=torch.max(compute_pe(all_resid_pre_act_patch_results, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs)),
        annot=False,
        xticklabels=True,
        center=0
    )

plt.title('Patching Effect of the Residual Stream')
plt.ylabel('Layer')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[264], line 2
#       1 sns.heatmap(
# ----> 2         compute_pe(all_resid_pre_act_patch_results, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs).T,
#       3         cmap='Blues',
#       4         vmin=torch.min(compute_pe(all_resid_pre_act_patch_results, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs)),
#       5         vmax=torch.max(compute_pe(all_resid_pre_act_patch_results, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs)),
#       6         annot=False,
#       7         xticklabels=True,
#       8         center=0
#       9     )
#      11 plt.title('Patching Effect of the Residual Stream')
#      12 plt.ylabel('Layer')
#
# Cell In[262], line 9, in compute_pe(patched_results, clean_logit_diffs, corrupted_logit_diffs)
#       8 def compute_pe(patched_results, clean_logit_diffs, corrupted_logit_diffs):
# ----> 9     return torch.mean(torch.stack(patched_results) - torch.tensor(corrupted_logit_diffs)[:, None, None], dim=0)
#
# RuntimeError: stack expects each tensor to be equal size, but got [36, 30] at entry 0 and [36, 36] at entry 9

# %%
sns.heatmap(
        compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs).T,
        cmap='Blues',
        vmin=torch.min(compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs)),
        vmax=torch.max(compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs)),
        yticklabels=labels,
        annot=False,
        xticklabels=True,
        center=0
    )

plt.title('Patching Effect of the Residual Stream')
plt.xlabel('Layer')
plt.show()

# %%
import pandas as pd

plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']

# Create a dataframe from the matrix
idx = ['Description Prompt', '(1) ICE 1st operand', '(+) ICD 1st operator', '(3) ICD 2nd operand', '(+) ICD 2nd operator', '(4) ICD 3rd operand', '(=) ICD Equal Sign', '(8) ICD Result', '(2) Task 1st operand', '(+) Task 1st operator', '(2) Task 2nd operand', '(+) Task 2nd operator', '(6) Task 3rd operand', '(=) Task Equal Sign']

df = pd.DataFrame(compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs_all, all_resid_pre_corrupted_logit_diffs_all).T, index=idx, columns=np.arange(36))

vmax=None

plt.figure(figsize=(8, 6))
sns.set(font_scale=1.1)
sns.set_style("whitegrid", {'axes.grid' : False})
ax = sns.heatmap(df, cmap="Blues", annot=False, fmt=".1f", cbar=True, vmax=vmax)
# set x-axis ticks to the range of unique layers
ax.set_xticks(range(36))

# # set x-axis labels to the range of unique layers
ax.set_xticklabels(range(36), fontsize=14, rotation=0)
plt.xlabel('Layer', fontsize=16, fontname='DeJavu Serif')

for index, label in enumerate(ax.xaxis.get_ticklabels()):
    if index % 5 != 0:
        label.set_visible(False)

# Y-axis adjustments: Make labels horizontal and remove the y-axis title
ax.set_yticklabels(ax.get_yticklabels(), fontsize=14, rotation=0)
plt.ylabel('') # Remove y-axis title

# Title and other adjustments
plt.title(f'Patching Effect of the Residual Stream ', fontsize=16, fontname='DeJavu Serif')

# Adjust color bar
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=14)

# Remove chart junk
sns.despine()

# plt.savefig("patching_effect_residual_stream.png", format='png', bbox_inches='tight')
plt.show()

# %%
sns.heatmap(
        compute_macro_mean(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-1,
        vmax=1,
        yticklabels=True,
        annot=False,
        xticklabels = labels
    )
# Out:
# <Axes: >

# %%
sns.heatmap(
        compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-0.2340,
        vmax=5.3958,
        yticklabels=True,
        annot=False,
        xticklabels = labels,
        center=0
    )

plt.title('Patching Effect of the Residual Stream')
plt.ylabel('Layer')
plt.show()

# %%
sns.heatmap(
        compute_micro_mean(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-1,
        vmax=1,
        yticklabels=True,
        annot=False,
        xticklabels = labels
    )
# Out:
# <Axes: >

# %%
torch.max(compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs))
# Out:
# tensor(5.3958)

# %%
torch.min(compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs))
# Out:
# tensor(-0.2340)

# %%
sns.heatmap(
        compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-0.2340,
        vmax=5.3958,
        yticklabels=True,
        annot=False,
        xticklabels = labels,
        center=0
    )

plt.title('Patching Effect of the Residual Stream')
plt.ylabel('Layer')
plt.show()

# %%
sns.heatmap(
        compute_pe(patched_results_operands_operators, all_resid_pre_clean_logit_diffs, all_resid_pre_corrupted_logit_diffs).T,
        cmap='RdBu',
        vmin=-0.2340,
        vmax=5.3958,
        yticklabels=labels,
        annot=False,
        xticklabels=True,
        center=0
    )

plt.title('Patching Effect of the Residual Stream')
plt.ylabel('Layer')
plt.show()

# %%
# attn_layer_act_patch_results = []
# attn_layer_clean_logit_diffs = []
# attn_layer_corrupted_logit_diffs = []
# for item in tqdm(corr_intervention_list):
#     patched_logit_diff, clean_logit_diff, corrupted_logit_diff = get_patched_result(item, activation_name='attn_layer')
#     attn_layer_act_patch_results.append(patched_logit_diff)
#     attn_layer_clean_logit_diffs.append(clean_logit_diff)
#     attn_layer_corrupted_logit_diffs.append(corrupted_logit_diff)

# attn_layer_patched_results_operands_operators = take_operands_and_operators_results(corr_intervention_list, attn_layer_act_patch_results)

# %%
# torch.save(attn_layer_act_patch_results, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_logit_diff_96_samples.pkl')
# torch.save(attn_layer_clean_logit_diffs, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_clean_logit_diff_96_samples.pkl')
# torch.save(attn_layer_corrupted_logit_diffs, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_corrupted_logit_diff_96_samples.pkl')

# %%
attn_layer_act_patch_results = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_logit_diff_96_samples.pkl')
attn_layer_clean_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_clean_logit_diff_96_samples.pkl')
attn_layer_corrupted_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_corrupted_logit_diff_96_samples.pkl')
# Out:
# /tmp/ipykernel_4067906/2055145764.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   attn_layer_act_patch_results = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_logit_diff_96_samples.pkl')
# /tmp/ipykernel_4067906/2055145764.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   attn_layer_clean_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_clean_logit_diff_96_samples.pkl')
# /tmp/ipykernel_4067906/2055145764.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   attn_layer_corrupted_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/attn_layer_corrupted_logit_diff_96_samples.pkl')

# %%
attn_layer_patched_results_operands_operators = take_operands_and_operators_results(corr_intervention_list, attn_layer_act_patch_results)

# %%
sns.heatmap(
        compute_macro_mean(attn_layer_patched_results_operands_operators, attn_layer_clean_logit_diffs, attn_layer_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-1,
        vmax=1,
        yticklabels=True,
        annot=False,
        xticklabels = labels
    )
# Out:
# <Axes: >

# %%
sns.heatmap(
        compute_micro_mean(attn_layer_patched_results_operands_operators, attn_layer_clean_logit_diffs, attn_layer_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-1,
        vmax=1,
        yticklabels=True,
        annot=False,
        xticklabels = labels
    )
# Out:
# <Axes: >

# %%
torch.min(compute_pe(attn_layer_patched_results_operands_operators, attn_layer_clean_logit_diffs, attn_layer_corrupted_logit_diffs))
# Out:
# tensor(-0.3092)

# %%
torch.max(compute_pe(attn_layer_patched_results_operands_operators, attn_layer_clean_logit_diffs, attn_layer_corrupted_logit_diffs))
# Out:
# tensor(0.6315)

# %%
sns.heatmap(
    compute_pe(attn_layer_patched_results_operands_operators, attn_layer_clean_logit_diffs, attn_layer_corrupted_logit_diffs),
    cmap='RdBu',
    yticklabels=True,
    annot=False,
    xticklabels = labels,
    vmin=-0.3092,
    vmax=0.6315,
    center=0
)

plt.title('Patching Effect of Attention Layer')
plt.ylabel('Layer')
plt.show()

# %%
sns.heatmap(
    compute_pe(attn_layer_patched_results_operands_operators, attn_layer_clean_logit_diffs, attn_layer_corrupted_logit_diffs).T,
    cmap='RdBu',
    yticklabels=labels,
    annot=False,
    xticklabels=True,
    vmin=-0.3092,
    vmax=0.6315,
    center=0
)

plt.title('Patching Effect of Attention Layer')
plt.ylabel('Layer')
plt.show()

# %%
# mlp_act_patch_results = []
# mlp_clean_logit_diffs = []
# mlp_corrupted_logit_diffs = []
# for item in tqdm(corr_intervention_list):
#     patched_logit_diff, clean_logit_diff, corrupted_logit_diff = get_patched_result(item, activation_name='mlp')
#     mlp_act_patch_results.append(patched_logit_diff)
#     mlp_clean_logit_diffs.append(clean_logit_diff)
#     mlp_corrupted_logit_diffs.append(corrupted_logit_diff)

# %%
mlp_act_patch_results = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/mlp_logit_diff_96_samples.pkl')
mlp_clean_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/mlp_clean_logit_diff_96_samples.pkl')
mlp_corrupted_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/mlp_corrupted_logit_diff_96_samples.pkl')
# Out:
# /tmp/ipykernel_4067906/111999855.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   mlp_act_patch_results = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/mlp_logit_diff_96_samples.pkl')
# /tmp/ipykernel_4067906/111999855.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   mlp_clean_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/mlp_clean_logit_diff_96_samples.pkl')
# /tmp/ipykernel_4067906/111999855.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   mlp_corrupted_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/mlp_corrupted_logit_diff_96_samples.pkl')

# %%
mlp_patched_results_operands_operators = take_operands_and_operators_results(corr_intervention_list, mlp_act_patch_results)

# %%
sns.heatmap(
        compute_macro_mean(mlp_patched_results_operands_operators, mlp_clean_logit_diffs, mlp_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-1,
        vmax=1,
        yticklabels=True,
        annot=False,
        xticklabels = labels
    )
# Out:
# <Axes: >

# %%
sns.heatmap(
        compute_micro_mean(mlp_patched_results_operands_operators, mlp_clean_logit_diffs, mlp_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-1,
        vmax=1,
        yticklabels=True,
        annot=False,
        xticklabels = labels
    )
# Out:
# <Axes: >

# %%
torch.min(compute_pe(mlp_patched_results_operands_operators, mlp_clean_logit_diffs, mlp_corrupted_logit_diffs))
# Out:
# tensor(-0.4089)

# %%
torch.max(compute_pe(mlp_patched_results_operands_operators, mlp_clean_logit_diffs, mlp_corrupted_logit_diffs))
# Out:
# tensor(1.8398)

# %%
sns.heatmap(
        compute_pe(mlp_patched_results_operands_operators, mlp_clean_logit_diffs, mlp_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-0.4089,
        vmax=1.8398,
        center=0,
        yticklabels=True,
        annot=False,
        xticklabels = labels
    )

plt.title('Patching Effect of the MLP')
plt.ylabel('Layer')
plt.show()

# %%
sns.heatmap(
        compute_pe(mlp_patched_results_operands_operators, mlp_clean_logit_diffs, mlp_corrupted_logit_diffs).T,
        cmap='RdBu',
        vmin=-0.4089,
        vmax=1.8398,
        center=0,
        yticklabels=labels,
        annot=False,
        xticklabels=True
    )

plt.title('Patching Effect of the MLP')
plt.ylabel('Layer')
plt.show()

# %% [markdown]
# Let's patch attention heads

# %%
# head_patch_results = []
# head_clean_logit_diffs = []
# head_corrupted_logit_diffs = []
# for item in tqdm(corr_intervention_list):
#     patched_logit_diff, clean_logit_diff, corrupted_logit_diff = get_patched_result(item, activation_name='head')
#     head_patch_results.append(patched_logit_diff)
#     head_clean_logit_diffs.append(clean_logit_diff)
#     head_corrupted_logit_diffs.append(corrupted_logit_diff)

# %%
# torch.save(head_patch_results, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_patch_logit_diff_96_samples.pkl')
# torch.save(head_clean_logit_diffs, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_clean_logit_diff_96_samples.pkl')
# torch.save(head_corrupted_logit_diffs, '/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_clean_corrupted_diff_96_samples.pkl')

# %%
head_patch_results = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_patch_logit_diff_96_samples.pkl')
head_clean_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_clean_logit_diff_96_samples.pkl')
head_corrupted_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_clean_corrupted_diff_96_samples.pkl')
# Out:
# /tmp/ipykernel_1393605/2746894999.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   head_patch_results = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_patch_logit_diff_96_samples.pkl')
# /tmp/ipykernel_1393605/2746894999.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   head_clean_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_clean_logit_diff_96_samples.pkl')
# /tmp/ipykernel_1393605/2746894999.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   head_corrupted_logit_diffs = torch.load('/mnt/qb/work/eickhoff/esx208/arithmetic-lm/data/patching_results_pythia_12b/head_clean_corrupted_diff_96_samples.pkl')

# %%
sns.heatmap(
        compute_macro_mean(head_patch_results, head_clean_logit_diffs, head_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-1,
        vmax=1,
        yticklabels=True,
        annot=False,
        xticklabels = True
    )
# Out:
# <Axes: >

# %%
sns.heatmap(
        compute_micro_mean(head_patch_results, head_clean_logit_diffs, head_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-1,
        vmax=1,
        yticklabels=True,
        annot=False,
        xticklabels = True
    )
# Out:
# <Axes: >

# %%
torch.min(compute_pe(head_patch_results, head_clean_logit_diffs, head_corrupted_logit_diffs))
# Out:
# tensor(-0.3835)

# %%
torch.max(compute_pe(head_patch_results, head_clean_logit_diffs, head_corrupted_logit_diffs))
# Out:
# tensor(0.7194)

# %%
sns.heatmap(
        compute_pe(head_patch_results, head_clean_logit_diffs, head_corrupted_logit_diffs),
        cmap='RdBu',
        vmin=-0.3835,
        vmax=0.7194,
        center=0,
        yticklabels=True,
        annot=False,
        xticklabels = True
    )
# Out:
# <Axes: >
